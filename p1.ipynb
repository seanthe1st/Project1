# %%
#Dataset : https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset
#Matplotlib : https://matplotlib.org/stable/api/pyplot_summary.html
#Seaborn : https://seaborn.pydata.org/api.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(('Netflix Userbase.csv'),sep=',')
display(df)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
df["Join Date"].value_counts()
# Out:
# 05-11-22    33
# 30-06-22    31
# 16-07-22    30
# 17-07-22    29
# 04-11-22    29
#             ..
# 21-04-22     1
# 30-10-21     1
# 23-11-21     1
# 24-03-23     1
# 15-01-22     1
# Name: Join Date, Length: 300, dtype: int64

# %%
df["Last Payment Date"].value_counts()
# Out:
# 28-06-23    164
# 09-07-23    154
# 27-06-23    148
# 03-07-23    146
# 06-07-23    146
# 29-06-23    144
# 10-07-23    140
# 07-07-23    139
# 30-06-23    133
# 04-07-23    131
# 01-07-23    131
# 02-07-23    129
# 11-07-23    128
# 05-07-23    126
# 08-07-23    126
# 26-06-23    114
# 25-06-23     79
# 12-07-23     77
# 24-06-23     40
# 13-07-23     39
# 23-06-23     24
# 22-06-23     18
# 14-07-23     16
# 15-07-23      6
# 20-06-23      1
# 10-06-23      1
# Name: Last Payment Date, dtype: int64

# %%
df["Subscription Type"].value_counts()
# Out:
# Basic       999
# Standard    768
# Premium     733
# Name: Subscription Type, dtype: int64

# %%
subs = 'Basic', 'Standard', 'Premium'
counts = [999, 768, 733]
plot1 = plt.pie(counts, labels=subs, autopct='%1.1f%%', shadow=True, startangle=90, explode = (0.05,0.0,0.0))
plt.title("Subscription Plans Distribution")
# Out:
# Text(0.5, 1.0, 'Subscription Plans Distribution')

# %%
df["Age"].value_counts()
# Out:
# 39    116
# 30    116
# 28    115
# 31    115
# 41    114
# 47    111
# 37    107
# 35    105
# 29    104
# 40    103
# 42    102
# 48    101
# 46     99
# 36     99
# 49     97
# 43     94
# 33     93
# 51     93
# 32     92
# 45     89
# 38     89
# 34     88
# 27     87
# 44     86
# 50     84
# 26      1
# Name: Age, dtype: int64

# %%
plot2 = sns.boxplot(df, x = "Age", y = "Gender", linewidth = 1).set(title="Age vs Gender Boxplot")

# %%
plot3 = sns.countplot(df, x="Device", hue="Gender", palette = "dark:#5A9_r").set(title="Gender vs Device Used")

# %%
df["Device"].value_counts()
# Out:
# Laptop        636
# Tablet        633
# Smartphone    621
# Smart TV      610
# Name: Device, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_3460\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   User ID  Monthly Revenue       Age
# User ID          1.000000        -0.004809  0.008065
# Monthly Revenue -0.004809         1.000000 -0.021143
# Age              0.008065        -0.021143  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
cat1 = {'Basic': 0, 'Standard': 1, 'Premium': 2}
df["Subscription Type"] = df["Subscription Type"].replace(cat1)
df
# Out:
#       User ID  Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1                  0               10  15-01-22          10-06-23
# 1           2                  2               15  05-09-21          22-06-23
# 2           3                  1               12  28-02-23          27-06-23
# 3           4                  1               12  10-07-22          26-06-23
# 4           5                  0               10  01-05-23          28-06-23
# ...       ...                ...              ...       ...               ...
# 2495     2496                  2               14  25-07-22          12-07-23
# 2496     2497                  0               15  04-08-22          14-07-23
# 2497     2498                  1               12  09-08-22          15-07-23
# 2498     2499                  1               13  12-08-22          12-07-23
# 2499     2500                  0               15  13-08-22          12-07-23
#
# ...

# %%
cat2 = {'Male': 0, 'Female': 1}
df["Gender"] = df["Gender"].replace(cat2)
df
# Out:
#       User ID  Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1                  0               10  15-01-22          10-06-23
# 1           2                  2               15  05-09-21          22-06-23
# 2           3                  1               12  28-02-23          27-06-23
# 3           4                  1               12  10-07-22          26-06-23
# 4           5                  0               10  01-05-23          28-06-23
# ...       ...                ...              ...       ...               ...
# 2495     2496                  2               14  25-07-22          12-07-23
# 2496     2497                  0               15  04-08-22          14-07-23
# 2497     2498                  1               12  09-08-22          15-07-23
# 2498     2499                  1               13  12-08-22          12-07-23
# 2499     2500                  0               15  13-08-22          12-07-23
#
# ...

# %%
cat3 = {'Laptop': 0, 'Tablet': 1, 'Smartphone': 2, 'Smart TV': 3}
df["Device"] = df["Device"].replace(cat3)
df
# Out:
#       User ID  Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1                  0               10  15-01-22          10-06-23
# 1           2                  2               15  05-09-21          22-06-23
# 2           3                  1               12  28-02-23          27-06-23
# 3           4                  1               12  10-07-22          26-06-23
# 4           5                  0               10  01-05-23          28-06-23
# ...       ...                ...              ...       ...               ...
# 2495     2496                  2               14  25-07-22          12-07-23
# 2496     2497                  0               15  04-08-22          14-07-23
# 2497     2498                  1               12  09-08-22          15-07-23
# 2498     2499                  1               13  12-08-22          12-07-23
# 2499     2500                  0               15  13-08-22          12-07-23
#
# ...

# %%
df.corr()
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_3460\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     User ID  Subscription Type  Monthly Revenue       Age  \
# User ID            1.000000          -0.001470        -0.004809  0.008065
# Subscription Type -0.001470           1.000000         0.025063 -0.016243
# Monthly Revenue   -0.004809           0.025063         1.000000 -0.021143
# Age                0.008065          -0.016243        -0.021143  1.000000
# Gender             0.015089          -0.013815         0.006139  0.039600
# Device             0.030697           0.006602        -0.030935 -0.016024
#
#                      Gender    Device
# User ID            0.015089  0.030697
# Subscription Type -0.013815  0.006602
# Monthly Revenue    0.006139 -0.030935
# ...

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(), cmap = "Reds", annot = True)
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_3460\1173359592.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = "Reds", annot = True)
# <Axes: >
